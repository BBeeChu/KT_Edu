# %%
import pandas as pd
import numpy as np
import zipfile
    
# import data
zf = zipfile.ZipFile('../content/anonymisedData.zip')

registrations = pd.read_csv(zf.open('studentRegistration.csv'))
courseInfo = pd.read_csv(zf.open('courses.csv'))
students = pd.read_csv(zf.open('studentInfo.csv'))
student_vle = pd.read_csv(zf.open('studentVle.csv'))
vle_info = pd.read_csv(zf.open('vle.csv'))
student_assessments = pd.read_csv(
    zf.open('studentAssessment.csv'), skiprows=[128223, 64073])
assessments_info = pd.read_csv(zf.open('assessments.csv'))
index_columns = ['code_module','code_presentation','id_student']

# %%
index_columns = ['code_module', 'code_presentation', 'id_student']
# Registrations
full_registrations = pd.merge(
    students, registrations, on=index_columns, validate='1:1')
full_registrations = pd.merge(full_registrations, courseInfo,
                              on=['code_module', 'code_presentation'], validate='many_to_one')
full_registrations.dropna(
    subset=['date_registration', 'imd_band'], inplace=True)

# %%
full_registrations.drop(columns=['imd_band', 'age_band', 'num_of_prev_attempts', 'studied_credits', 'disability', 'date_registration', 'date_unregistration'], inplace=True)

# %%
full_registrations = pd.merge(full_registrations, student_vle, how = 'left', on =['code_module', 'code_presentation', 'id_student'], validate='m:m')

# %%
full_registrations = pd.merge(full_registrations, assessments_info, how = 'left', on =['code_module', 'code_presentation'], validate= 'm:m' )

# %%
full_registrations.drop(columns=['date_y', 'weight'], inplace=True)

# %%
full_registrations.rename(columns={'date_x': 'date'})
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
full_registrations = full_registrations[full_registrations['date']>0]

# %%
full_registrations.groupby(by=['code_module', 'code_presentation']).count().reset_index()
# Out:
#    code_module code_presentation  id_student   gender   region  \
# 0          AAA             2013J      172250   172250   172250
# 1          AAA             2014J      166810   166810   166810
# 2          BBB             2013B      394607   394607   394607
# 3          BBB             2013J      448603   448603   448603
# 4          BBB             2014B      270909   270909   270909
# 5          BBB             2014J      434860   434860   434860
# 6          CCC             2014B      452663   452663   452663
# 7          CCC             2014J      649571   649571   649571
# 8          DDD             2013B      497772   497772   497772
# 9          DDD             2013J      641807   641807   641807
# 10         DDD             2014B      349700   349700   349700
# 11         DDD             2014J      527592   527592   527592
# 12         EEE             2013J      332008   332008   332008
# 13         EEE             2014B      191561   191561   191561
# 14         EEE             2014J      380317   380317   380317
# 15         FFF             2013B      875057   875057   875057
# 16         FFF             2013J     1103394  1103394  1103394
# 17         FFF             2014B      641279   641279   641279
# 18         FFF             2014J     1139338  1139338  1139338
# 19         GGG             2013J      145472   145472   145472
# 20         GGG             2014B      122959   122959   122959
# 21         GGG             2014J      117533   117533   117533
#
#     highest_education  final_result  module_presentation_length  id_site  \
# 0              172250        172250                      172250   172245
# 1              166810        166810                      166810   166802
# 2              394607        394607                      394607   394380
# 3              448603        448603                      448603   448241
# 4              270909        270909                      270909   270598
# 5              434860        434860                      434860   434490
# 6              452663        452663                      452663   452421
# 7              649571        649571                      649571   649384
# 8              497772        497772                      497772   497691
# 9              641807        641807                      641807   641644
# 10             349700        349700                      349700   349593
# 11             527592        527592                      527592   527439
# 12             332008        332008                      332008   331924
# 13             191561        191561                      191561   191491
# 14             380317        380317                      380317   380228
# 15             875057        875057                      875057   874961
# 16            1103394       1103394                     1103394  1103215
# 17             641279        641279                      641279   641148
# 18            1139338       1139338                     1139338  1139101
# 19             145472        145472                      145472   145415
# 20             122959        122959                      122959   122899
# 21             117533        117533                      117533   117482
#
#        date  sum_click
# 0    172245     172245
# 1    166802     166802
# 2    394380     394380
# 3    448241     448241
# 4    270598     270598
# 5    434490     434490
# 6    452421     452421
# 7    649384     649384
# 8    497691     497691
# 9    641644     641644
# 10   349593     349593
# 11   527439     527439
# 12   331924     331924
# 13   191491     191491
# 14   380228     380228
# 15   874961     874961
# 16  1103215    1103215
# 17   641148     641148
# 18  1139101    1139101
# 19   145415     145415
# 20   122899     122899
# 21   117482     117482

# %%
full_registrations
# Out:
#          code_module code_presentation  id_student gender  \
# 21               AAA             2013J       11391      M
# 22               AAA             2013J       11391      M
# 23               AAA             2013J       11391      M
# 24               AAA             2013J       11391      M
# 25               AAA             2013J       11391      M
# ...              ...               ...         ...    ...
# 10056057         GGG             2014J     2684003      F
# 10056058         GGG             2014J     2684003      F
# 10056059         GGG             2014J     2684003      F
# 10056060         GGG             2014J     2684003      F
# 10056061         GGG             2014J     2684003      F
#
#                        region highest_education final_result  \
# 21        East Anglian Region  HE Qualification         Pass
# 22        East Anglian Region  HE Qualification         Pass
# 23        East Anglian Region  HE Qualification         Pass
# 24        East Anglian Region  HE Qualification         Pass
# 25        East Anglian Region  HE Qualification         Pass
# ...                       ...               ...          ...
# 10056057     Yorkshire Region  HE Qualification  Distinction
# 10056058     Yorkshire Region  HE Qualification  Distinction
# 10056059     Yorkshire Region  HE Qualification  Distinction
# 10056060     Yorkshire Region  HE Qualification  Distinction
# 10056061     Yorkshire Region  HE Qualification  Distinction
#
#           module_presentation_length   id_site   date  sum_click
# 21                               268  546681.0    1.0        5.0
# 22                               268  546900.0    1.0        1.0
# 23                               268  547009.0    1.0        1.0
# 24                               268  546986.0    1.0        1.0
# 25                               268  547013.0    1.0        2.0
# ...                              ...       ...    ...        ...
# 10056057                         269  896961.0  205.0       13.0
# 10056058                         269  896959.0  205.0        2.0
# 10056059                         269  896943.0  219.0        1.0
# 10056060                         269  896961.0  219.0       31.0
# 10056061                         269  896961.0  219.0        8.0
#
# [9331815 rows x 11 columns]
